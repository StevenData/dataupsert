# %%
df = spark.read.parquet('wasbs://censusdatacontainer@azureopendatastorage.blob.core.windows.net/release/us_population_county/year=20*/*.parquet')
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div style="display: block; unicode-bidi: embed; white-space: pre-wrap; word-wrap: break-word; word-break: break-all; font-family: Menlo, monospace;font-size: 13px; color: #555; margin-left: 4px; line-height: 19px;">root
# -- decennialTime: string (nullable = true)
# -- stateName: string (nullable = true)
# -- countyName: string (nullable = true)
# -- population: integer (nullable = true)
# -- race: string (nullable = true)
# -- sex: string (nullable = true)
# -- minAge: integer (nullable = true)
# -- maxAge: integer (nullable = true)
#
# </div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div style="display: block; unicode-bidi: embed; white-space: pre-wrap; word-wrap: break-word; word-break: break-all; font-family: Menlo, monospace;font-size: 13px; color: #555; margin-left: 4px; line-height: 19px;">+-------------+---------+---------------+----------+--------------------+------+------+------+
# decennialTime|stateName|     countyName|population|                race|   sex|minAge|maxAge|
# +-------------+---------+---------------+----------+--------------------+------+------+------+
#          2010|    Texas|Crockett County|       123|         WHITE ALONE|  Male|     5|     9|
# ...
